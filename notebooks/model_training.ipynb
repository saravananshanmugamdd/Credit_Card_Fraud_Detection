# %%
import pandas as pd
import numpy as np

from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report
)

# %%
Data_path=Path(r"C:\Credit_card_fraud_detection\data\raw\creditcard.csv")

df=pd.read_csv(Data_path)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
x=df.drop(["Class"],axis=1)
y=df["Class"]

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (213605, 30)
# (213605,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (71202, 30)
# (71202,)

# %%
scaler=StandardScaler()

x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %%
smote=SMOTE()

x_train_smote,y_train_smote=smote.fit_resample(x_train_scaled,y_train)

# %%
lr=LogisticRegression()
dt=DecisionTreeClassifier()
rfc=RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
lr.fit(x_train_smote, y_train_smote)

lr_pred=lr.predict(x_test_scaled)

# %%
dt.fit(x_train_smote, y_train_smote)

dt_pred=dt.predict(x_test_scaled)

# %%
rfc.fit(x_train_smote, y_train_smote)

rfc_pred=rfc.predict(x_test_scaled)

# %%
def evaluate_model(model_name, actual,prediction):
    print(f"\n {model_name}")
    print("-"*50)

    print("accuracy :", accuracy_score(actual,prediction))
    print("precision_score",precision_score(actual,prediction))
    print("recall_score",recall_score(actual,prediction))
    print("f1_score",f1_score(actual,prediction))
    print("classification_report",classification_report(actual,prediction))

# %%
evaluate_model(
    "logistic"
)
